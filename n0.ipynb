# %%
import mitreattack.attackToExcel.attackToExcel as attackToExcel
import mitreattack.attackToExcel.stixToDf as stixToDf

# download and parse ATT&CK STIX data
attackdata = attackToExcel.get_stix_data("enterprise-attack")
techniques_data = stixToDf.techniquesToDf(attackdata, "enterprise-attack")
# Out:
# 2023-07-19 13:12:01.601 | INFO     | mitreattack.attackToExcel.attackToExcel:get_stix_data:69 - Downloading ATT&CK data from github.com/mitre/cti
# parsing techniques: 100%|██████████| 607/607 [00:00<00:00, 1165.82it/s]
# parsing relationships for type=technique: 100%|██████████| 16530/16530 [00:00<00:00, 65323.53it/s]

# %%
techniques_data = stixToDf.techniquesToDf(attackdata, "enterprise-attack")
print (techniques_data.keys())
techniques_df = techniques_data["techniques"]
techniques_df.head(10)
# Out:
# parsing techniques: 100%|██████████| 607/607 [00:00<00:00, 1206.12it/s]
# parsing relationships for type=technique: 100%|██████████| 16530/16530 [00:00<00:00, 64824.59it/s]
# dict_keys(['techniques', 'procedure examples', 'associated mitigations', 'citations'])
#             ID                                               name  \
# 256      T1548                  Abuse Elevation Control Mechanism
# 50   T1548.002  Abuse Elevation Control Mechanism: Bypass User...
# 433  T1548.004  Abuse Elevation Control Mechanism: Elevated Ex...
# 258  T1548.001  Abuse Elevation Control Mechanism: Setuid and ...
# 52   T1548.003  Abuse Elevation Control Mechanism: Sudo and Su...
# 521      T1134                          Access Token Manipulation
# 257  T1134.002  Access Token Manipulation: Create Process with...
# 349  T1134.003  Access Token Manipulation: Make and Impersonat...
# 362  T1134.004     Access Token Manipulation: Parent PID Spoofing
# 429  T1134.005   Access Token Manipulation: SID-History Injection
#
#                                            description  \
# 256  Adversaries may circumvent mechanisms designed...
# 50   Adversaries may bypass UAC mechanisms to eleva...
# 433  Adversaries may leverage the <code>Authorizati...
# 258  An adversary may abuse configurations where an...
# 52   Adversaries may perform sudo caching and/or us...
# 521  Adversaries may modify access tokens to operat...
# 257  Adversaries may create a new process with an e...
# 349  Adversaries may make new tokens and impersonat...
# 362  Adversaries may spoof the parent process ident...
# 429  Adversaries may use SID-History Injection to e...
#
#                                                url           created  \
# 256      https://attack.mitre.org/techniques/T1548   30 January 2020
# 50   https://attack.mitre.org/techniques/T1548/002   30 January 2020
# 433  https://attack.mitre.org/techniques/T1548/004   30 January 2020
# 258  https://attack.mitre.org/techniques/T1548/001   30 January 2020
# 52   https://attack.mitre.org/techniques/T1548/003   30 January 2020
# 521      https://attack.mitre.org/techniques/T1134  14 December 2017
# 257  https://attack.mitre.org/techniques/T1134/002  18 February 2020
# 349  https://attack.mitre.org/techniques/T1134/003  18 February 2020
# 362  https://attack.mitre.org/techniques/T1134/004  18 February 2020
# 429  https://attack.mitre.org/techniques/T1134/005  18 February 2020
#
#         last modified version                                tactics  \
# 256     21 April 2023     1.1  Defense Evasion, Privilege Escalation
# 50      21 April 2023     2.1  Defense Evasion, Privilege Escalation
# 433   19 October 2022     1.0  Defense Evasion, Privilege Escalation
# 258     15 March 2023     1.1  Defense Evasion, Privilege Escalation
# 52      14 March 2022     1.0  Defense Evasion, Privilege Escalation
# 521     30 March 2023     2.0  Defense Evasion, Privilege Escalation
# 257     11 April 2023     1.2  Defense Evasion, Privilege Escalation
# 349     11 April 2023     1.1  Defense Evasion, Privilege Escalation
# 362       03 May 2022     1.0  Defense Evasion, Privilege Escalation
# 429  09 February 2021     1.0  Defense Evasion, Privilege Escalation
#
#                                              detection              platforms  \
# 256  Monitor the file system for files that have th...  Linux, Windows, macOS
# 50   There are many ways to perform UAC bypasses wh...                Windows
# 433  Consider monitoring for <code>/usr/libexec/sec...                  macOS
# 258  Monitor the file system for files that have th...           Linux, macOS
# 52   On Linux, auditd can alert every time a user's...           Linux, macOS
# 521  If an adversary is using a standard command-li...                Windows
# 257  If an adversary is using a standard command-li...                Windows
# 349  If an adversary is using a standard command-li...                Windows
# 362  Look for inconsistencies between the various f...                Windows
# 429  Examine data in user’s SID-History attributes ...                Windows
#
#      ... is sub-technique  sub-technique of  \
# 256  ...            False               NaN
# 50   ...             True             T1548
# 433  ...             True             T1548
# 258  ...             True             T1548
# 52   ...             True             T1548
# 521  ...            False               NaN
# 257  ...             True             T1134
# 349  ...             True             T1134
# 362  ...             True             T1134
# 429  ...             True             T1134
#
#                                      defenses bypassed  \
# 256                                                NaN
# 50                        Windows User Account Control
# 433                                                NaN
# 258                                                NaN
# 52                                                 NaN
# 521  Heuristic Detection, Host Forensic Analysis, S...
# 257  File system access controls, System access con...
# 349  File system access controls, System access con...
# 362        Heuristic Detection, Host Forensic Analysis
# 429                                                NaN
#
#                                           contributors   permissions required  \
# 256                                                NaN    Administrator, User
# 50                         Casey Smith; Stefan Kanthak    Administrator, User
# 433  Erika Noerenberg, @gutterchurl, Carbon Black; ...    Administrator, User
# 258                                                NaN                   User
# 52                                                 NaN                   User
# 521  Jared Atkinson, @jaredcatkinson; Robby Winches...    Administrator, User
# 257                       Jonny Johnson; Vadim Khrykov                    NaN
# 349                                      Jonny Johnson    Administrator, User
# 362                  Wayne Silva, F-Secure Countercept    Administrator, User
# 429  Alain Homewood, Insomnia Security; Vincent Le ...  Administrator, SYSTEM
#
#     supports remote system requirements impact type effective permissions  \
# 256             NaN                 NaN         NaN                   NaN
# 50              NaN                 NaN         NaN         Administrator
# 433             NaN                 NaN         NaN                  root
# 258             NaN                 NaN         NaN                   NaN
# 52              NaN                 NaN         NaN                  root
# 521             NaN                 NaN         NaN                SYSTEM
# 257             NaN                 NaN         NaN                   NaN
# 349             NaN                 NaN         NaN                SYSTEM
# 362             NaN                 NaN         NaN                   NaN
# 429             NaN                 NaN         NaN                   NaN
#
#                                 relationship citations
# 256                          ,(Citation: Github UACMe)
# 50   (Citation: Trend Micro Tick November 2019),(Ci...
# 433         (Citation: Carbon Black Shlayer Feb 2019),
# 258  (Citation: OSX Keydnap malware),(Citation: ANS...
# 52   (Citation: Cobalt Strike Manual 4.3 November 2...
# 521  (Citation: PowerSploit Documentation),(Citatio...
# 257  (Citation: GitHub PoshC2),(Citation: McAfee Ba...
# 349  (Citation: cobaltstrike manual),(Citation: Sen...
# 362  (Citation: CobaltStrike Daddy May 2017),(Citat...
# 429  (Citation: Github PowerShell Empire),(Citation...
#
# [10 rows x 21 columns]
