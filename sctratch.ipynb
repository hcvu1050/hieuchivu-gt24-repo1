# %%
import matplotlib.pyplot as plt

# %%
training_loss = [0.8915860652923584, 0.6242129802703857, 0.7102217674255371, 0.6779444217681885, 0.6737833619117737, 0.6735294461250305]
validation_loss = [0.5090712904930115, 0.7446485757827759, 0.7788713574409485, 0.7535215020179749, 0.6758723258972168, 0.6569448113441467]

# %%
plt.plot(range(1, len(training_loss) + 1), training_loss, label='Training Loss')
plt.plot(range(1, len(validation_loss) + 1), validation_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
